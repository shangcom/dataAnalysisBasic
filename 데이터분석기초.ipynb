# %% [markdown]
# <a href="https://colab.research.google.com/github/hayaboy/dataAnalysisBasic/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EA%B8%B0%EC%B4%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# help(pd.read_csv)

# %%
pd.read_csv("./sample_data/car_register_work.csv")
# Out:
#    2015  15807517
# 0  2016   16505364
# 1  2017   17121786
# 2  2018   17663188
# 3  2019   18071723
# 4  2020   18686570
# 5  2021   19168262
# 6  2022   19647975
# 7  2023   20079294

# %%
# numpy 공부

# %%
import numpy as np

# %%
# help(np.array)

# %%
year1=np.array(['2017', '2018', '2019'])

# %%
type(year1)
# Out:
# numpy.ndarray

# %%
np.ndim(year1)
# Out:
# 1

# %%
car_count1=np.array([17121786, 17663188, 18071723])

# %%
# help(pd.DataFrame)

# %%
# 1차원 리스트

# %%
hong1=['홍일동', 166, 30,'남']
hong2=['홍이동', 168, 60,'여']
hong3=['홍삼동', 170, 26,'여']
hong4=['홍사동', 172, 40,'남']
hong5=['홍오동', 174, 90,'남']

# %%
stu_2list=[hong1, hong2, hong3, hong4, hong5]

# %%
# 2차원 리스트

# %%
pd.DataFrame(stu_2list)
# Out:
#      0    1   2  3
# 0  홍일동  166  30  남
# 1  홍이동  168  60  여
# 2  홍삼동  170  26  여
# 3  홍사동  172  40  남
# 4  홍오동  174  90  남

# %%
# 1차원 배열

# %%
stu_name=np.array(['홍일동','홍이동','홍삼동','홍사동','홍오동'])
stu_height=np.array([166,168,170,172,174])
stu_weight=np.array([30,60,26,40,90])
stu_sung=np.array(['남','여','여','남','남'])

# %%
# 2차원 배열

# %%
pd.DataFrame([stu_name,stu_height,stu_weight, stu_sung])
# Out:
#      0    1    2    3    4
# 0  홍일동  홍이동  홍삼동  홍사동  홍오동
# 1  166  168  170  172  174
# 2   30   60   26   40   90
# 3    남    여    여    남    남

# %%
df1=pd.DataFrame([stu_name,stu_height,stu_weight, stu_sung])

# %%
df1.T
# Out:
#      0    1   2  3
# 0  홍일동  166  30  남
# 1  홍이동  168  60  여
# 2  홍삼동  170  26  여
# 3  홍사동  172  40  남
# 4  홍오동  174  90  남

# %%
df2=df1.T

# %%
df2_copy=df2.copy()

# %%
df2_copy
# Out:
#      0    1   2  3
# 0  홍일동  166  30  남
# 1  홍이동  168  60  여
# 2  홍삼동  170  26  여
# 3  홍사동  172  40  남
# 4  홍오동  174  90  남

# %%
df2.columns=['이름', '키', '몸무게', '성별']

# %%
df2
# Out:
#     이름    키 몸무게 성별
# 0  홍일동  166  30  남
# 1  홍이동  168  60  여
# 2  홍삼동  170  26  여
# 3  홍사동  172  40  남
# 4  홍오동  174  90  남

# %%
# 데이터 프레임 요약(기술 통계)
# 데이터 요약

# %%
df2.describe()
# Out:
#          이름    키  몸무게 성별
# count     5    5    5  5
# unique    5    5    5  2
# top     홍일동  166   30  남
# freq      1    1    1  3

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      5 non-null      object
#  1   키       5 non-null      object
#  2   몸무게     5 non-null      object
#  3   성별      5 non-null      object
# dtypes: object(4)
# memory usage: 288.0+ bytes

# %%
df2.이름
# Out:
# 0    홍일동
# 1    홍이동
# 2    홍삼동
# 3    홍사동
# 4    홍오동
# Name: 이름, dtype: object

# %%
type(df2.이름)
# Out:
# pandas.core.series.Series

# %%
df2.loc[0]
# Out:
# 이름     홍일동
# 키      166
# 몸무게     30
# 성별       남
# Name: 0, dtype: object

# %%
type(df2.loc[0])
# Out:
# pandas.core.series.Series
